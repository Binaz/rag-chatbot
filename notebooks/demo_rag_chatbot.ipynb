# %% [markdown]
# # Energy & Sustainability RAG Chatbot – Demo
# This notebook demonstrates a clean working version of the RAG chatbot that answers questions using Energy & Sustainability research papers.

# %% [markdown]
# ## Dependencies
# Make sure the following packages are installed:
# - PyMuPDF
# - Sentence-Transformers
# - FAISS
# - Hugging Face Transformers
# - Gradio

# %% [markdown]
# ## Example Queries
# Try asking:
# 1. "What are the environmental impacts of chemical spills?"
# 2. "Explain sustainable energy methods discussed in recent papers."
# 3. "How can PFAS contamination be reduced?"

# %% [markdown]
# ## Below are few Samples of RAG chatbot

# %% [markdown]
# ***Question 1. Which Papers discuss hybrid renewable energy systems?***

# %% [markdown]
# ![Example_1.png](data:image/png;base64,...)

# %% [markdown]
# ***Question 2. What are the latest trends in energy storage technology?***

# %% [markdown]
# ![Example_2.png](data:image/png;base64,...)

# %% [markdown]
# ***Question 3. What are the main sources of sustainable energy?***

# %% [markdown]
# ![Example_3.png](data:image/png;base64,...)

# %% [markdown]
# ***Question 4. How have energy efficiency programs impacted industries?***

# %% [markdown]
# ![Example_5.png](data:image/png;base64,...)

# %% [markdown]
# ***Question 5. Challenges of using non-renewable energy***

# %% [markdown]
# ![Example_6.png](data:image/png;base64,...)

# %% [markdown]
# ***Question 6: What are the environmental impacts on marine life?***

# %% [markdown]
# ![Example_4.png](data:image/png;base64,...)

# %% [markdown]
# ***Question 7. Limitations of renewable energy?***

# %% [markdown]
# ![Example_7.png](data:image/png;base64,...)

# %% [markdown]
# ***Question 8: Solar as renewable energy***

# %% [markdown]
# ![Example_8.png](data:image/png;base64,...)
